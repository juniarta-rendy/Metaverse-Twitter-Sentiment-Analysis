# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
seed = 0
np.random.seed(seed)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'whitegrid')

import twint
import nest_asyncio
nest_asyncio.apply()

import datetime as dt
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from wordcloud import WordCloud

from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Embedding, Dense, Dropout, LSTM
from keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder

# %%
tweets_data = pd.read_csv('../Cleaning/Clean_Dataset.csv')
tweets = tweets_data[['Clean_Text','Stop_Words_Text','Stemming_Text', 'New_Location', 'indonlp_sentiment', 'Lexicon_Score', 'Lexicon_Sentiment']]

# %%
tweets.head()
# Out:
#                                           Clean_Text  \
# 0  cina dan as terus bersaing mengembangkan tekno...
# 1  katanya mau metaverse tapi down melulu bagaima...
# 2  mungkin facebook sudah berencana menjadi metav...
# 3  bersaing dengan perusahaan kelas dunia untuk m...
# 4  staff dengan mah lulusan kampus terbaik lah ka...
#
#                                      Stop_Words_Text  \
# 0  cina as bersaing mengembangkan teknologi terba...
# 1         katanya metaverse down melulu deh mas zuck
# 2  mungkin facebook berencana metaverse menyiapka...
# 3  bersaing perusahaan kelas dunia mencapai sekto...
# 4  staff mah lulusan kampus terbaik attitude krit...
#
#                                        Stemming_Text New_Location  \
# 0  cina as saing kembang teknologi baru usaha neg...      Jakarta
# 1            kata metaverse down melulu deh mas zuck    Indonesia
# 2  mungkin facebook rencana metaverse siap diem s...    Indonesia
# 3  saing usaha kelas dunia capai sektor publik sw...    Indonesia
# 4  staff mah lulus kampus baik attitude kritik bu...          NaN
#
#   indonlp_sentiment  Lexicon_Score Lexicon_Sentiment
# 0           neutral              9          positive
# 1          negative             -2          negative
# 2          positive             24          positive
# 3           neutral              8          positive
# 4          negative              3          positive

# %%
def cleaningText(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text) # remove mentions
    text = re.sub(r'#[A-Za-z0-9]+', '', text) # remove hashtag
    text = re.sub(r'RT[\s]', '', text) # remove RT
    text = re.sub(r"http\S+", '', text) # remove link
    text = re.sub(r'[0-9]+', '', text) # remove numbers

    text = text.replace('\n', ' ') # replace new line into space
    text = text.translate(str.maketrans('', '', string.punctuation)) # remove all punctuations
    text = text.strip(' ') # remove characters space from both left and right text
    return text

def casefoldingText(text): # Converting all the characters in a text into lower case
    text = text.lower() 
    return text

def tokenizingText(text):
    text = word_tokenize(text)
    return text

def filteringText(text): # Remove stopwors in a text
    listStopwords = set(stopwords.words('indonesian'))
    filtered = []
    for txt in text:
        if txt not in listStopwords:
            filtered.append(txt)
    text = filtered 
    return text

def stemmingText(text): # Reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    text = [stemmer.stem(word) for word in text]
    return text

def toSentence(text):
    sentence = ' '.join(word for word in text)
    return sentence

# %%
tweets['text_preprocessed'] = tweets['Stemming_Text'].apply(lambda x: tokenizingText(x))

# %%
tweets.head()
# Out:
#                                           Clean_Text  \
# 0  cina dan as terus bersaing mengembangkan tekno...
# 1  katanya mau metaverse tapi down melulu bagaima...
# 2  mungkin facebook sudah berencana menjadi metav...
# 3  bersaing dengan perusahaan kelas dunia untuk m...
# 4  staff dengan mah lulusan kampus terbaik lah ka...
#
#                                      Stop_Words_Text  \
# 0  cina as bersaing mengembangkan teknologi terba...
# 1         katanya metaverse down melulu deh mas zuck
# 2  mungkin facebook berencana metaverse menyiapka...
# 3  bersaing perusahaan kelas dunia mencapai sekto...
# 4  staff mah lulusan kampus terbaik attitude krit...
#
#                                        Stemming_Text New_Location  \
# 0  cina as saing kembang teknologi baru usaha neg...      Jakarta
# 1            kata metaverse down melulu deh mas zuck    Indonesia
# 2  mungkin facebook rencana metaverse siap diem s...    Indonesia
# 3  saing usaha kelas dunia capai sektor publik sw...    Indonesia
# 4  staff mah lulus kampus baik attitude kritik bu...          NaN
#
#   indonlp_sentiment  Lexicon_Score Lexicon_Sentiment  \
# 0           neutral              9          positive
# 1          negative             -2          negative
# 2          positive             24          positive
# 3           neutral              8          positive
# 4          negative              3          positive
#
#                                    text_preprocessed
# 0  [cina, as, saing, kembang, teknologi, baru, us...
# 1    [kata, metaverse, down, melulu, deh, mas, zuck]
# 2  [mungkin, facebook, rencana, metaverse, siap, ...
# 3  [saing, usaha, kelas, dunia, capai, sektor, pu...
# 4  [staff, mah, lulus, kampus, baik, attitude, kr...

# %% [markdown]
# ### Analysis and Visualization

# %% [markdown]
# ##### Comparison Sentiment Polarity on Tweets Data

# %% [markdown]
# ##### Top 10 Positive and Negative Tweet Sentiments

# %%
pd.set_option('display.max_colwidth', 3000)
positive_tweets = tweets[tweets['Lexicon_Sentiment'] == 'positive']
positive_tweets = positive_tweets[['Clean_Text', 'Lexicon_Score','Lexicon_Sentiment']].sort_values(by = 'Lexicon_Score', ascending = False)[0:10].reset_index(drop=True)
positive_tweets.index += 1
positive_tweets[0:10]
# Out:
#                                                                                                                                                                                                                                                                                            Clean_Text  \
# 1                                                                                inovasi nya ada kripto inovasi nya ada web inovasi nya ada nft inovasi nya ada metaverse internet itu teknologi nya inovasi nya ada tiktok inovasi nya ada twitter inovasi nya ada youtube inovasi nya ada instagram
# 2                                     ada yang typo blockchain itu teknologi nya inovasi nya ada kripto inovasi nya ada web inovasi nya ada nft inovasi nya ada metaverse internet itu teknologi nya inovasi nya ada tiktok inovasi nya ada twitter inovasi nya ada youtube inovasi nya ada instagram
# 3                                                                                                 mau tidak habiskan bensin mau tidak membakar fosil mau tidak melubangi ozon mau tidak repot antri mau tidak repot di jalan mau tidak naik kolesterol naik darah tinggi maka menikahlah di metaverse
# 4                                    kamu mungkin tahu atau punya koleksi sepatu adidas di dunia nyata tapi mungkin kamu belum tahu atau dengar mengenai sepatu adidas koleksi khusus satu ini nah buat kamu pecinta sepatu yuk berkumpul untuk membaca ulasan menarik dari brand kesayangan kamu ini
# 5                                                       saran mau nyaman enjoy kedepan mulai mau tahu urusan orang mau tahu urusan orang dikit apa itu metaverse dan web dulu instagram yt fb dan twitter pas web di lirik nya sudah terlambat banget pas sudah melambung tinggi baru gunain web dyor
# 6                                                       di masa depan pelaku bisnis mampu mengembangkan potensi mereka dan merambah sampai ke dunia untuk memberikan pengalaman baru kepada para pelanggan mereka ungkap berbagai potensi bisnis dalam dunia di webinar ids peluang bisnis masa depan
# 7         metaverse diciptakan kegiatan utopia kaum kapitalis untuk menghindari dystopia padahal eksistensi manusia mencapai tujuan kebahagiaan dunia dan kedepan tetap dieksploitasi habis sama dengan menciptakan robot yng lebih kuat dari manusia menghasilkan pengganti pemimpin peradaban dunia
# 8                                        bisnis bersama pasangan suami istri ini bekerja sama dengan pengusaha rudy salim lesti dan billar terjun di dunia kripto dan metaverse ini sejak awal lalu sebelumnya lesti terjun ke bisnis fashion dan juga merambah ke bisnis kosmetik foto dok instagram
# 9                                belum kalau ternyata hidup yang kita kira nyata ini ternyata ilusi apakah kita ini sebenarnya sudah di metaverse lalu kalau ada metaverse apakah berarti kita akan mengalami ilusi diri dari diri yang sudah ilusi ilusi di dalam ilusi metaverse di dalam metaverse
# 10  tapi kebayang tidak yang ini sudah mulai ga make sense aku tahu justin timberlake sudah konser di metaverse steve aoki juga tapi how do you value sebuah tanah digital begitu kalau tanah daratan kan terbatas kalau digital yang beli nantinya kaya ajg ku kira tanahnya terbatas ternyata engga
#
#     Lexicon_Score Lexicon_Sentiment
# 1              62          positive
# 2              57          positive
# 3              47          positive
# 4              46          positive
# 5              43          positive
# 6              43          positive
# 7              42          positive
# 8              41          positive
# 9              41          positive
# 10             40          positive

# %%
pd.set_option('display.max_colwidth', 3000)
negative_tweets = tweets[tweets['Lexicon_Sentiment'] == 'negative']
negative_tweets = negative_tweets[['Clean_Text', 'Lexicon_Score','Lexicon_Sentiment']].sort_values(by = 'Lexicon_Score', ascending = True)[0:10].reset_index(drop=True)
negative_tweets.index += 1
negative_tweets[0:10]
# Out:
#                                                                                                                                                                                                                                                                                                                                        Clean_Text  \
# 1   yang nft demam metaverse dirjen pajak cawe ngewe meki ber belatung musisi siapa yang kena narkotika, psikotropika, dan obat terlarang intoleran parno sajen ketangkep adaaa saja yang sliweran netijen yang dedicated eyel an dengan bahasa ndakik as always saya mah bodo amatan fokus saya bukan yang diatas asal saya notice saja dh cukup
# 2                                                                       kenapa karena banyak polusi toxic kayak kalian yang mempeetanyakan kontribusi apa mereka iya polusi udara kekerasan kejahatan di dunia nyata adalah kalian yang menghina aespa di dunia maya mereka disana untuk membasmi kalian polusi kekerasan dan kejahatan metaverse
# 3                                                                                                                       tidak tahu juga seharusnya yang salah tuh pihak mtv nya terus juga kalau yang metaverse perfomance nya emang sudah masuk akal kok tapi kalau yang group of the year tidak tahu cuma pihak mtv doang yang tahu kok bisa si
# 4                                                                                      halah gausah jauh dan aneh metaverse ini itu deh noh streaming kamu dibenerin dulu sediain streaming yang layak yang proper jangan cuma negara tertentu saja yang ditampilin kalau sudah bisa streaming yang layak dan all court baru deh urusin yang lain
# 5                                                                            teknologi masuk kenegara ini butuh waktu lama contoh inget saja jaman internet smartphone social media dan lain-lain masuk sini butuh waktu yang cukup lama dari jaman dulu vr atau sejenisnya saja masih belum terlalu besar penggunaannya disini apalagi metaverse
# 6                                                                                                                                            ah sudah lah paling nanti dia ngelesnya itu yang bicara diri dia yang berasal dari metaverse yang berbeda kalau mau salahkan iya salah kan saja dr strange dan teman temannya jangan dia bingung kan
# 7                                                                     saya jadi maklum kalau metaverse itu bukan konsep yang jauh dan emang bakal jadi bagian immersif dari hidup saya selalu menganggap internet itu dunia yang berbeda bahkan saya akan terpisah dari rl tapi anak sekarang emang internet itu bagian hidup yang ga terpisahkan
# 8                                                       sebenernya tidak ada yang permasalahin loh kalau ada group lain pakai metaverse concept cuma tadi ada yang discredit konsepnya aes kalau aes tuh cuma avatar dan exp saja padahal jauh lebih dari itu no one tries to gatekeep that concept but kamu need to acknowledge who did it first
# 9                                                                                         anak muda negara lain sudah memikirkan metaverse dan investasi digital kita masih sibuk saling hujat saling fitnah demo ga jelas cari cari kesalahan orang kapan negara ini akan maju cukuplah kita ini nkri bukan bangsa arab yang hobi perang saudara
# 10                                                                                           menurut para fans hal seperti itu tidak boleh dikritik di dunia metaverse ala mereka ada dogma tidak boleh mengkritik membandingkan mengolok olok yang mulia dan yang mulia dengan lainnya jk ada yang kritik solusinya caci maki bullying dan lapor
#
#     Lexicon_Score Lexicon_Sentiment
# 1             -70          negative
# 2             -52          negative
# 3             -51          negative
# 4             -49          negative
# 5             -48          negative
# 6             -46          negative
# 7             -45          negative
# 8             -44          negative
# 9             -43          negative
# 10            -43          negative

# %% [markdown]
# ##### Word Cloud

# %%
#visualize word cloud

list_words=''
for tweet in tweets['text_preprocessed']:
    for word in tweet:
        list_words += ' '+(word)
        
wordcloud = WordCloud(width = 600, height = 400, background_color = 'black', min_font_size = 10).generate(list_words)
fig, ax = plt.subplots(figsize = (8, 6))
ax.set_title('Word Cloud of Tweets Data', fontsize = 18)
ax.grid(False)
ax.imshow((wordcloud))
fig.tight_layout(pad=0)
ax.axis('off')
plt.show()

# %% [markdown]
# #### Sentiment analysis Using LSTM

# %% [markdown]
# ###### Preprocessing Text Data

# %%
# Make text preprocessed (tokenized) to untokenized with toSentence Function
X = tweets['text_preprocessed'].apply(lambda x: toSentence(x))
max_features = 5000

# Tokenize text with specific maximum number of words to keep, based on word frequency
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(X.values)
X = tokenizer.texts_to_sequences(X.values)
X = pad_sequences(X)
X.shape
# Out:
# (47004, 79)

# %%
# Encode target data into numerical values
polarity_encode = {'negative' : 0, 'neutral' : 1, 'positive' : 2}
y = tweets['Lexicon_Sentiment'].map(polarity_encode).values
y = y.astype(int)

# Split the data (with composition data train 80%, data test 20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (37603, 79) (37603,)
# (9401, 79) (9401,)

# %%
np.unique(tweets['Lexicon_Sentiment'])
# Out:
# array(['negative', 'neutral', 'positive'], dtype=object)

# %%
type(y[0])
# Out:
# numpy.int32

# %% [markdown]
# ##### LSTM Model

# %%
def create_model(embed_dim = 16, hidden_unit = 16, dropout_rate = 0.2, optimizers = Adam, learning_rate = 0.001):
    model = Sequential()
    model.add(Embedding(input_dim = max_features, output_dim = embed_dim, input_length = X_train.shape[1]))
    model.add(LSTM(units = hidden_unit, activation = 'tanh'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units = 3, activation = 'softmax'))
    model.compile(loss = 'sparse_categorical_crossentropy', optimizer = optimizers(lr = learning_rate), metrics = ['accuracy'])
    print(model.summary())
    return model

# %%
# Hyperparameter tuning (to know the best hyperparameter for this model)

# Wrapper model with default hyperparameter values
model = KerasClassifier(build_fn = create_model, epochs = 25, batch_size=128) 

# Hyperparameters
embed_dim = [32, 64]
hidden_unit = [16, 32, 64]
dropout_rate = [0.2]
optimizers = [Adam, RMSprop]
learning_rate = [0.01, 0.001, 0.0001]
epochs = [10, 25]
batch_size = [128, 256]
param_grid = dict(embed_dim = embed_dim, hidden_unit = hidden_unit, dropout_rate = dropout_rate, 
                  learning_rate = learning_rate, optimizers = optimizers, epochs = epochs, batch_size = batch_size)

# Evaluation model with GridSearchCV to know what the best hyperparameter for model 
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = 3)
grid_result = grid.fit(X_train, y_train)

results = pd.DataFrame()
results['means'] = grid_result.cv_results_['mean_test_score']
results['stds'] = grid_result.cv_results_['std_test_score']
results['params'] = grid_result.cv_results_['params']
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
results.to_csv(r'gridsearchcv_results_lexicon.csv', index = False, header = True)
results.sort_values(by='means', ascending = False).reset_index(drop=True)
# Out:
# C:\Users\Juniarta\AppData\Local\Temp\ipykernel_1936\828351765.py:4: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, epochs = 25, batch_size=128)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 79, 32)            160000
#
#  lstm (LSTM)                 (None, 16)                3136
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense (Dense)               (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# C:\Users\Juniarta\anaconda3\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 196/196 [==============================] - 8s 28ms/step - loss: 0.8211 - accuracy: 0.6195
# Epoch 2/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6634 - accuracy: 0.7255
# Epoch 3/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5763 - accuracy: 0.7665
# Epoch 4/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.4964 - accuracy: 0.7970
# Epoch 5/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.4337 - accuracy: 0.8226
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.3805 - accuracy: 0.8410
# Epoch 7/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.3395 - accuracy: 0.8606
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.2986 - accuracy: 0.8776
# Epoch 9/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.2744 - accuracy: 0.8879
# Epoch 10/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.2510 - accuracy: 0.8980
# 98/98 [==============================] - 2s 9ms/step - loss: 1.5257 - accuracy: 0.6422
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 79, 32)            160000
#
#  lstm_1 (LSTM)               (None, 16)                3136
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_1 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 29ms/step - loss: 0.8031 - accuracy: 0.6347
# Epoch 2/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.6490 - accuracy: 0.7350
# Epoch 3/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5573 - accuracy: 0.7749
# Epoch 4/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.4826 - accuracy: 0.8024
# Epoch 5/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.4161 - accuracy: 0.8303
# Epoch 6/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.3589 - accuracy: 0.8520
# Epoch 7/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.3212 - accuracy: 0.8674
# Epoch 8/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.2863 - accuracy: 0.8849
# Epoch 9/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.2598 - accuracy: 0.8946
# Epoch 10/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.2355 - accuracy: 0.9038
# 98/98 [==============================] - 1s 9ms/step - loss: 1.6403 - accuracy: 0.6350
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 79, 32)            160000
#
#  lstm_2 (LSTM)               (None, 16)                3136
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 29ms/step - loss: 0.8095 - accuracy: 0.6260
# Epoch 2/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.6591 - accuracy: 0.7310
# Epoch 3/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5726 - accuracy: 0.7682
# Epoch 4/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.4909 - accuracy: 0.8005
# Epoch 5/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.4295 - accuracy: 0.8250
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.3847 - accuracy: 0.8428
# Epoch 7/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.3400 - accuracy: 0.8619
# Epoch 8/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3099 - accuracy: 0.8731
# Epoch 9/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.2894 - accuracy: 0.8833
# Epoch 10/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.2696 - accuracy: 0.8907
# 98/98 [==============================] - 2s 11ms/step - loss: 1.4416 - accuracy: 0.6495
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 79, 32)            160000
#
#  lstm_3 (LSTM)               (None, 16)                3136
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# C:\Users\Juniarta\anaconda3\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:140: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 196/196 [==============================] - 9s 31ms/step - loss: 0.8074 - accuracy: 0.6316
# Epoch 2/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.6785 - accuracy: 0.7161
# Epoch 3/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.6196 - accuracy: 0.7441
# Epoch 4/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.5686 - accuracy: 0.7692
# Epoch 5/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.5172 - accuracy: 0.7924
# Epoch 6/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.4781 - accuracy: 0.8082
# Epoch 7/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.4417 - accuracy: 0.8261
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.4034 - accuracy: 0.8428
# Epoch 9/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.3708 - accuracy: 0.8550
# Epoch 10/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3415 - accuracy: 0.8670
# 98/98 [==============================] - 2s 10ms/step - loss: 1.0893 - accuracy: 0.6561
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 79, 32)            160000
#
#  lstm_4 (LSTM)               (None, 16)                3136
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 30ms/step - loss: 0.8001 - accuracy: 0.6415
# Epoch 2/10
# 196/196 [==============================] - 12s 62ms/step - loss: 0.6734 - accuracy: 0.7230
# Epoch 3/10
# 196/196 [==============================] - 5s 27ms/step - loss: 0.6099 - accuracy: 0.7542
# Epoch 4/10
# 196/196 [==============================] - 5s 27ms/step - loss: 0.5564 - accuracy: 0.7777
# Epoch 5/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5115 - accuracy: 0.7973
# Epoch 6/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.4680 - accuracy: 0.8143
# Epoch 7/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.4299 - accuracy: 0.8282
# Epoch 8/10
# 196/196 [==============================] - 6s 28ms/step - loss: 0.3977 - accuracy: 0.8445
# Epoch 9/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.3654 - accuracy: 0.8572
# Epoch 10/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.3405 - accuracy: 0.8689
# 98/98 [==============================] - 2s 9ms/step - loss: 1.0863 - accuracy: 0.6533
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 79, 32)            160000
#
#  lstm_5 (LSTM)               (None, 16)                3136
#
#  dropout_5 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 9s 32ms/step - loss: 0.7993 - accuracy: 0.6400
# Epoch 2/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6736 - accuracy: 0.7224
# Epoch 3/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6138 - accuracy: 0.7497
# Epoch 4/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5593 - accuracy: 0.7738
# Epoch 5/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5104 - accuracy: 0.7932
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.4683 - accuracy: 0.8115
# Epoch 7/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.4299 - accuracy: 0.8280
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.3934 - accuracy: 0.8407
# Epoch 9/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.3609 - accuracy: 0.8576
# Epoch 10/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.3334 - accuracy: 0.8674
# 98/98 [==============================] - 2s 10ms/step - loss: 1.1129 - accuracy: 0.6499
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 79, 32)            160000
#
#  lstm_6 (LSTM)               (None, 16)                3136
#
#  dropout_6 (Dropout)         (None, 16)                0
#
#  dense_6 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 30ms/step - loss: 0.9275 - accuracy: 0.5287
# Epoch 2/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7499 - accuracy: 0.6800
# Epoch 3/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6616 - accuracy: 0.7280
# Epoch 4/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6137 - accuracy: 0.7523
# Epoch 5/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5854 - accuracy: 0.7648
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5563 - accuracy: 0.7762
# Epoch 7/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5332 - accuracy: 0.7874
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5088 - accuracy: 0.7957
# Epoch 9/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.4823 - accuracy: 0.8104
# Epoch 10/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.4597 - accuracy: 0.8202
# 98/98 [==============================] - 2s 10ms/step - loss: 0.9257 - accuracy: 0.6569
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 79, 32)            160000
#
#  lstm_7 (LSTM)               (None, 16)                3136
#
#  dropout_7 (Dropout)         (None, 16)                0
#
#  dense_7 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 30ms/step - loss: 0.9382 - accuracy: 0.5150
# Epoch 2/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7529 - accuracy: 0.6788
# Epoch 3/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6611 - accuracy: 0.7327
# Epoch 4/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.6152 - accuracy: 0.7543
# Epoch 5/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.5833 - accuracy: 0.7689
# Epoch 6/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.5557 - accuracy: 0.7814
# Epoch 7/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.5295 - accuracy: 0.7918
# Epoch 8/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.5043 - accuracy: 0.8040
# Epoch 9/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.4814 - accuracy: 0.8130
# Epoch 10/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.4557 - accuracy: 0.8237
# 98/98 [==============================] - 2s 10ms/step - loss: 0.9255 - accuracy: 0.6586
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 79, 32)            160000
#
#  lstm_8 (LSTM)               (None, 16)                3136
#
#  dropout_8 (Dropout)         (None, 16)                0
#
#  dense_8 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 10s 37ms/step - loss: 0.9259 - accuracy: 0.5283
# Epoch 2/10
# 196/196 [==============================] - 8s 40ms/step - loss: 0.7409 - accuracy: 0.6812
# Epoch 3/10
# 196/196 [==============================] - 7s 36ms/step - loss: 0.6572 - accuracy: 0.7331
# Epoch 4/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.6153 - accuracy: 0.7550
# Epoch 5/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5858 - accuracy: 0.7685
# Epoch 6/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5592 - accuracy: 0.7760
# Epoch 7/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5316 - accuracy: 0.7865
# Epoch 8/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5050 - accuracy: 0.7987
# Epoch 9/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.4832 - accuracy: 0.8105
# Epoch 10/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.4590 - accuracy: 0.8185
# 98/98 [==============================] - 2s 9ms/step - loss: 0.9486 - accuracy: 0.6560
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 79, 32)            160000
#
#  lstm_9 (LSTM)               (None, 16)                3136
#
#  dropout_9 (Dropout)         (None, 16)                0
#
#  dense_9 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 28ms/step - loss: 0.9247 - accuracy: 0.5355
# Epoch 2/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.7885 - accuracy: 0.6612
# Epoch 3/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.7196 - accuracy: 0.6971
# Epoch 4/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6816 - accuracy: 0.7202
# Epoch 5/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6562 - accuracy: 0.7326
# Epoch 6/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6354 - accuracy: 0.7425
# Epoch 7/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6210 - accuracy: 0.7496
# Epoch 8/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6064 - accuracy: 0.7573
# Epoch 9/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.5934 - accuracy: 0.7634
# Epoch 10/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5823 - accuracy: 0.7679
# 98/98 [==============================] - 1s 9ms/step - loss: 0.7689 - accuracy: 0.6836
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 79, 32)            160000
#
#  lstm_10 (LSTM)              (None, 16)                3136
#
#  dropout_10 (Dropout)        (None, 16)                0
#
#  dense_10 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 27ms/step - loss: 0.9100 - accuracy: 0.5525
# Epoch 2/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.7638 - accuracy: 0.6688
# Epoch 3/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6976 - accuracy: 0.7110
# Epoch 4/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6619 - accuracy: 0.7319
# Epoch 5/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6393 - accuracy: 0.7453
# Epoch 6/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6212 - accuracy: 0.7500
# Epoch 7/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6046 - accuracy: 0.7591
# Epoch 8/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5942 - accuracy: 0.7631
# Epoch 9/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5832 - accuracy: 0.7710
# Epoch 10/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5702 - accuracy: 0.7727
# 98/98 [==============================] - 2s 9ms/step - loss: 0.7755 - accuracy: 0.6803
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, 79, 32)            160000
#
#  lstm_11 (LSTM)              (None, 16)                3136
#
#  dropout_11 (Dropout)        (None, 16)                0
#
#  dense_11 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 27ms/step - loss: 0.9233 - accuracy: 0.5260
# Epoch 2/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.7777 - accuracy: 0.6605
# Epoch 3/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.7038 - accuracy: 0.7076
# Epoch 4/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6662 - accuracy: 0.7311
# Epoch 5/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6424 - accuracy: 0.7410
# Epoch 6/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6224 - accuracy: 0.7491
# Epoch 7/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.6076 - accuracy: 0.7553
# Epoch 8/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5949 - accuracy: 0.7625
# Epoch 9/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5807 - accuracy: 0.7687
# Epoch 10/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.5659 - accuracy: 0.7773
# 98/98 [==============================] - 1s 9ms/step - loss: 0.7964 - accuracy: 0.6795
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_12 (Embedding)    (None, 79, 32)            160000
#
#  lstm_12 (LSTM)              (None, 16)                3136
#
#  dropout_12 (Dropout)        (None, 16)                0
#
#  dense_12 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 29ms/step - loss: 1.0582 - accuracy: 0.4775
# Epoch 2/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.9624 - accuracy: 0.4805
# Epoch 3/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9488 - accuracy: 0.4972
# Epoch 4/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9289 - accuracy: 0.5147
# Epoch 5/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9045 - accuracy: 0.5484
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8820 - accuracy: 0.5795
# Epoch 7/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8569 - accuracy: 0.6093
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8290 - accuracy: 0.6322
# Epoch 9/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8027 - accuracy: 0.6526
# Epoch 10/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7787 - accuracy: 0.6705
# 98/98 [==============================] - 2s 10ms/step - loss: 0.7933 - accuracy: 0.6546
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_13 (Embedding)    (None, 79, 32)            160000
#
#  lstm_13 (LSTM)              (None, 16)                3136
#
#  dropout_13 (Dropout)        (None, 16)                0
#
#  dense_13 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 30ms/step - loss: 1.0555 - accuracy: 0.4890
# Epoch 2/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9619 - accuracy: 0.4901
# Epoch 3/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9489 - accuracy: 0.4928
# Epoch 4/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9321 - accuracy: 0.4993
# Epoch 5/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9157 - accuracy: 0.5098
# Epoch 6/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.9023 - accuracy: 0.5247
# Epoch 7/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8846 - accuracy: 0.5447
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8547 - accuracy: 0.5824
# Epoch 9/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8213 - accuracy: 0.6198
# Epoch 10/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.7954 - accuracy: 0.6455
# 98/98 [==============================] - 2s 10ms/step - loss: 0.8220 - accuracy: 0.6144
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_14 (Embedding)    (None, 79, 32)            160000
#
#  lstm_14 (LSTM)              (None, 16)                3136
#
#  dropout_14 (Dropout)        (None, 16)                0
#
#  dense_14 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 30ms/step - loss: 1.0488 - accuracy: 0.4771
# Epoch 2/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.9573 - accuracy: 0.4924
# Epoch 3/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.9478 - accuracy: 0.4953
# Epoch 4/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.9313 - accuracy: 0.4995
# Epoch 5/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.9127 - accuracy: 0.5275
# Epoch 6/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.8851 - accuracy: 0.5846
# Epoch 7/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.8513 - accuracy: 0.6322
# Epoch 8/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.8179 - accuracy: 0.6484
# Epoch 9/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.7945 - accuracy: 0.6634
# Epoch 10/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.7729 - accuracy: 0.6787
# 98/98 [==============================] - 2s 10ms/step - loss: 0.8053 - accuracy: 0.6529
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_15 (Embedding)    (None, 79, 32)            160000
#
#  lstm_15 (LSTM)              (None, 16)                3136
#
#  dropout_15 (Dropout)        (None, 16)                0
#
#  dense_15 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 29ms/step - loss: 1.0695 - accuracy: 0.4549
# Epoch 2/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9918 - accuracy: 0.4709
# Epoch 3/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9596 - accuracy: 0.4813
# Epoch 4/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9497 - accuracy: 0.4841
# Epoch 5/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9353 - accuracy: 0.5006
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9211 - accuracy: 0.5189
# Epoch 7/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9036 - accuracy: 0.5366
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8883 - accuracy: 0.5599
# Epoch 9/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8678 - accuracy: 0.5876
# Epoch 10/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8473 - accuracy: 0.6049
# 98/98 [==============================] - 2s 10ms/step - loss: 0.8297 - accuracy: 0.6256
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_16 (Embedding)    (None, 79, 32)            160000
#
#  lstm_16 (LSTM)              (None, 16)                3136
#
#  dropout_16 (Dropout)        (None, 16)                0
#
#  dense_16 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 29ms/step - loss: 1.0486 - accuracy: 0.4906
# Epoch 2/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9738 - accuracy: 0.4950
# Epoch 3/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9490 - accuracy: 0.4967
# Epoch 4/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.9306 - accuracy: 0.5115
# Epoch 5/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.9082 - accuracy: 0.5303
# Epoch 6/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8844 - accuracy: 0.5618
# Epoch 7/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8613 - accuracy: 0.5956
# Epoch 8/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8397 - accuracy: 0.6181
# Epoch 9/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8238 - accuracy: 0.6300
# Epoch 10/10
# 196/196 [==============================] - 6s 31ms/step - loss: 0.8092 - accuracy: 0.6455
# 98/98 [==============================] - 2s 10ms/step - loss: 0.8310 - accuracy: 0.6127
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_17 (Embedding)    (None, 79, 32)            160000
#
#  lstm_17 (LSTM)              (None, 16)                3136
#
#  dropout_17 (Dropout)        (None, 16)                0
#
#  dense_17 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 163,187
# Trainable params: 163,187
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 28ms/step - loss: 1.0748 - accuracy: 0.4863
# Epoch 2/10
# 196/196 [==============================] - 6s 29ms/step - loss: 1.0002 - accuracy: 0.4932
# Epoch 3/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.9550 - accuracy: 0.4910
# Epoch 4/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.9399 - accuracy: 0.4944
# Epoch 5/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.9237 - accuracy: 0.5022
# Epoch 6/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.9066 - accuracy: 0.5194
# Epoch 7/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.8932 - accuracy: 0.5424
# Epoch 8/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.8743 - accuracy: 0.5701
# Epoch 9/10
# 196/196 [==============================] - 6s 29ms/step - loss: 0.8578 - accuracy: 0.5988
# Epoch 10/10
# 196/196 [==============================] - 6s 30ms/step - loss: 0.8391 - accuracy: 0.6236
# 98/98 [==============================] - 1s 9ms/step - loss: 0.8424 - accuracy: 0.6241
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_18 (Embedding)    (None, 79, 32)            160000
#
#  lstm_18 (LSTM)              (None, 32)                8320
#
#  dropout_18 (Dropout)        (None, 32)                0
#
#  dense_18 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 168,419
# Trainable params: 168,419
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 9s 33ms/step - loss: 0.8133 - accuracy: 0.6269
# Epoch 2/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.6596 - accuracy: 0.7287
# Epoch 3/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.5747 - accuracy: 0.7642
# Epoch 4/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.4958 - accuracy: 0.7956
# Epoch 5/10
# 196/196 [==============================] - 7s 35ms/step - loss: 0.4299 - accuracy: 0.8204
# Epoch 6/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.3794 - accuracy: 0.8415
# Epoch 7/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.3365 - accuracy: 0.8595
# Epoch 8/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.2964 - accuracy: 0.8759
# Epoch 9/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.2664 - accuracy: 0.8908
# Epoch 10/10
# 196/196 [==============================] - 7s 34ms/step - loss: 0.2416 - accuracy: 0.9017
# 98/98 [==============================] - 2s 13ms/step - loss: 1.5739 - accuracy: 0.6401
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_19 (Embedding)    (None, 79, 32)            160000
#
#  lstm_19 (LSTM)              (None, 32)                8320
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_19 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 168,419
# Trainable params: 168,419
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 9s 32ms/step - loss: 0.8045 - accuracy: 0.6350
# Epoch 2/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.6521 - accuracy: 0.7309
# Epoch 3/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.5654 - accuracy: 0.7714
# Epoch 4/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.4907 - accuracy: 0.7974
# Epoch 5/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.4254 - accuracy: 0.8229
# Epoch 6/10
# 196/196 [==============================] - 7s 33ms/step - loss: 0.3657 - accuracy: 0.8477
# Epoch 7/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.3259 - accuracy: 0.8648
# Epoch 8/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.2931 - accuracy: 0.8810
# Epoch 9/10
# 196/196 [==============================] - 7s 36ms/step - loss: 0.2642 - accuracy: 0.8925
# Epoch 10/10
# 196/196 [==============================] - 7s 35ms/step - loss: 0.2383 - accuracy: 0.9039
# 98/98 [==============================] - 2s 12ms/step - loss: 1.6864 - accuracy: 0.6398
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_20 (Embedding)    (None, 79, 32)            160000
#
#  lstm_20 (LSTM)              (None, 32)                8320
#
#  dropout_20 (Dropout)        (None, 32)                0
#
#  dense_20 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 168,419
# Trainable params: 168,419
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 8s 31ms/step - loss: 0.8038 - accuracy: 0.6333
# Epoch 2/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.6540 - accuracy: 0.7313
# Epoch 3/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.5648 - accuracy: 0.7710
# Epoch 4/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.4915 - accuracy: 0.7991
# Epoch 5/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.4334 - accuracy: 0.8214
# Epoch 6/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3845 - accuracy: 0.8393
# Epoch 7/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3325 - accuracy: 0.8625
# Epoch 8/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3023 - accuracy: 0.8761
# Epoch 9/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.2721 - accuracy: 0.8915
# Epoch 10/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.2384 - accuracy: 0.9038
# 98/98 [==============================] - 2s 11ms/step - loss: 1.6136 - accuracy: 0.6481
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_21 (Embedding)    (None, 79, 32)            160000
#
#  lstm_21 (LSTM)              (None, 32)                8320
#
#  dropout_21 (Dropout)        (None, 32)                0
#
#  dense_21 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 168,419
# Trainable params: 168,419
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 9s 31ms/step - loss: 0.8134 - accuracy: 0.6285
# Epoch 2/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.6827 - accuracy: 0.7139
# Epoch 3/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.6231 - accuracy: 0.7418
# Epoch 4/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.5649 - accuracy: 0.7689
# Epoch 5/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.5182 - accuracy: 0.7926
# Epoch 6/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.4712 - accuracy: 0.8108
# Epoch 7/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.4325 - accuracy: 0.8281
# Epoch 8/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3916 - accuracy: 0.8466
# Epoch 9/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3556 - accuracy: 0.8611
# Epoch 10/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3202 - accuracy: 0.8755
# 98/98 [==============================] - 2s 12ms/step - loss: 1.1371 - accuracy: 0.6449
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_22 (Embedding)    (None, 79, 32)            160000
#
#  lstm_22 (LSTM)              (None, 32)                8320
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_22 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 168,419
# Trainable params: 168,419
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 196/196 [==============================] - 9s 32ms/step - loss: 0.8033 - accuracy: 0.6333
# Epoch 2/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.6725 - accuracy: 0.7233
# Epoch 3/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.6150 - accuracy: 0.7503
# Epoch 4/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.5640 - accuracy: 0.7706
# Epoch 5/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.5154 - accuracy: 0.7930
# Epoch 6/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.4693 - accuracy: 0.8129
# Epoch 7/10
# 196/196 [==============================] - 6s 33ms/step - loss: 0.4256 - accuracy: 0.8311
# Epoch 8/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3828 - accuracy: 0.8491
# Epoch 9/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3454 - accuracy: 0.8653
# Epoch 10/10
# 196/196 [==============================] - 6s 32ms/step - loss: 0.3088 - accuracy: 0.8806
# ...
# =================================================================
# Total params: 332,515
# Trainable params: 332,515
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 98/98 [==============================] - 7s 45ms/step - loss: 1.0592 - accuracy: 0.4767
# Epoch 2/25
# 98/98 [==============================] - 4s 46ms/step - loss: 0.9738 - accuracy: 0.4874
# Epoch 3/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.9543 - accuracy: 0.4902
# Epoch 4/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.9378 - accuracy: 0.5044
# Epoch 5/25
# 98/98 [==============================] - 5s 46ms/step - loss: 0.9178 - accuracy: 0.5215
# Epoch 6/25
# 98/98 [==============================] - 5s 46ms/step - loss: 0.9009 - accuracy: 0.5430
# Epoch 7/25
# 98/98 [==============================] - 5s 46ms/step - loss: 0.8835 - accuracy: 0.5684
# Epoch 8/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.8634 - accuracy: 0.5950
# Epoch 9/25
# 98/98 [==============================] - 5s 46ms/step - loss: 0.8415 - accuracy: 0.6165
# Epoch 10/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.8165 - accuracy: 0.6357
# Epoch 11/25
# 98/98 [==============================] - 5s 48ms/step - loss: 0.7997 - accuracy: 0.6428
# Epoch 12/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7828 - accuracy: 0.6560
# Epoch 13/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7684 - accuracy: 0.6671
# Epoch 14/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7556 - accuracy: 0.6732
# Epoch 15/25
# 98/98 [==============================] - 5s 48ms/step - loss: 0.7418 - accuracy: 0.6839
# Epoch 16/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7308 - accuracy: 0.6906
# Epoch 17/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7192 - accuracy: 0.6977
# Epoch 18/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7095 - accuracy: 0.7018
# Epoch 19/25
# 98/98 [==============================] - 5s 48ms/step - loss: 0.7015 - accuracy: 0.7080
# Epoch 20/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6944 - accuracy: 0.7116
# Epoch 21/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6830 - accuracy: 0.7177
# Epoch 22/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6768 - accuracy: 0.7238
# Epoch 23/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6702 - accuracy: 0.7234
# Epoch 24/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6635 - accuracy: 0.7274
# Epoch 25/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6574 - accuracy: 0.7317
# 49/49 [==============================] - 2s 19ms/step - loss: 0.7405 - accuracy: 0.6878
# Model: "sequential_412"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_412 (Embedding)   (None, 79, 64)            320000
#
#  lstm_412 (LSTM)             (None, 32)                12416
#
#  dropout_412 (Dropout)       (None, 32)                0
#
#  dense_412 (Dense)           (None, 3)                 99
#
# =================================================================
# Total params: 332,515
# Trainable params: 332,515
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 98/98 [==============================] - 7s 45ms/step - loss: 1.0706 - accuracy: 0.4774
# Epoch 2/25
# 98/98 [==============================] - 5s 46ms/step - loss: 0.9811 - accuracy: 0.4917
# Epoch 3/25
# 98/98 [==============================] - 5s 50ms/step - loss: 0.9534 - accuracy: 0.4948
# Epoch 4/25
# 98/98 [==============================] - 5s 48ms/step - loss: 0.9415 - accuracy: 0.4995
# Epoch 5/25
# 98/98 [==============================] - 5s 46ms/step - loss: 0.9273 - accuracy: 0.5071
# Epoch 6/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.9137 - accuracy: 0.5228
# Epoch 7/25
# 98/98 [==============================] - 5s 49ms/step - loss: 0.9003 - accuracy: 0.5415
# Epoch 8/25
# 98/98 [==============================] - 6s 57ms/step - loss: 0.8869 - accuracy: 0.5696
# Epoch 9/25
# 98/98 [==============================] - 5s 51ms/step - loss: 0.8710 - accuracy: 0.5924
# Epoch 10/25
# 98/98 [==============================] - 6s 57ms/step - loss: 0.8490 - accuracy: 0.6169
# Epoch 11/25
# 98/98 [==============================] - 6s 56ms/step - loss: 0.8269 - accuracy: 0.6358
# Epoch 12/25
# 98/98 [==============================] - 6s 62ms/step - loss: 0.8078 - accuracy: 0.6472
# Epoch 13/25
# 98/98 [==============================] - 6s 56ms/step - loss: 0.7931 - accuracy: 0.6584
# Epoch 14/25
# 98/98 [==============================] - 6s 59ms/step - loss: 0.7803 - accuracy: 0.6654
# Epoch 15/25
# 98/98 [==============================] - 5s 49ms/step - loss: 0.7659 - accuracy: 0.6729
# Epoch 16/25
# 98/98 [==============================] - 5s 49ms/step - loss: 0.7554 - accuracy: 0.6796
# Epoch 17/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7413 - accuracy: 0.6888
# Epoch 18/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7323 - accuracy: 0.6915
# Epoch 19/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7210 - accuracy: 0.6972
# Epoch 20/25
# 98/98 [==============================] - 5s 48ms/step - loss: 0.7125 - accuracy: 0.7015
# Epoch 21/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.7023 - accuracy: 0.7032
# Epoch 22/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6918 - accuracy: 0.7089
# Epoch 23/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.6846 - accuracy: 0.7118
# Epoch 24/25
# 98/98 [==============================] - 5s 49ms/step - loss: 0.6773 - accuracy: 0.7168
# Epoch 25/25
# 98/98 [==============================] - 5s 52ms/step - loss: 0.6708 - accuracy: 0.7193
# 49/49 [==============================] - 2s 20ms/step - loss: 0.7689 - accuracy: 0.6685
# Model: "sequential_413"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_413 (Embedding)   (None, 79, 64)            320000
#
#  lstm_413 (LSTM)             (None, 32)                12416
#
#  dropout_413 (Dropout)       (None, 32)                0
#
#  dense_413 (Dense)           (None, 3)                 99
#
# =================================================================
# Total params: 332,515
# Trainable params: 332,515
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 98/98 [==============================] - 7s 46ms/step - loss: 1.0551 - accuracy: 0.4772
# Epoch 2/25
# 98/98 [==============================] - 5s 53ms/step - loss: 0.9651 - accuracy: 0.4927
# Epoch 3/25
# 98/98 [==============================] - 5s 49ms/step - loss: 0.9450 - accuracy: 0.4991
# Epoch 4/25
# 98/98 [==============================] - 5s 47ms/step - loss: 0.9290 - accuracy: 0.5092
# Epoch 5/25
# 98/98 [==============================] - 5s 49ms/step - loss: 0.9140 - accuracy: 0.5293
# Epoch 6/25
# 98/98 [==============================] - 5s 54ms/step - loss: 0.9001 - accuracy: 0.5504
# Epoch 7/25
# 98/98 [==============================] - 5s 50ms/step - loss: 0.8816 - accuracy: 0.5758
# Epoch 8/25
# 98/98 [==============================] - 5s 50ms/step - loss: 0.8615 - accuracy: 0.5997
# Epoch 9/25
# 98/98 [==============================] - 5s 49ms/step - loss: 0.8387 - accuracy: 0.6245
# Epoch 10/25
# 98/98 [==============================] - 5s 50ms/step - loss: 0.8167 - accuracy: 0.6350
# Epoch 11/25
# 98/98 [==============================] - 6s 63ms/step - loss: 0.8001 - accuracy: 0.6502
# Epoch 12/25
# 98/98 [==============================] - 5s 56ms/step - loss: 0.7834 - accuracy: 0.6619
# Epoch 13/25
# 98/98 [==============================] - 6s 57ms/step - loss: 0.7670 - accuracy: 0.6716
# Epoch 14/25
# 98/98 [==============================] - 5s 55ms/step - loss: 0.7567 - accuracy: 0.6775
# Epoch 15/25
# 98/98 [==============================] - 5s 55ms/step - loss: 0.7446 - accuracy: 0.6836
# Epoch 16/25
# 98/98 [==============================] - 6s 57ms/step - loss: 0.7322 - accuracy: 0.6888
# Epoch 17/25
# 98/98 [==============================] - 5s 52ms/step - loss: 0.7207 - accuracy: 0.6967
# Epoch 18/25
# 98/98 [==============================] - 5s 55ms/step - loss: 0.7095 - accuracy: 0.7025
# Epoch 19/25
# 98/98 [==============================] - 5s 56ms/step - loss: 0.6996 - accuracy: 0.7085
# Epoch 20/25
# 98/98 [==============================] - 5s 54ms/step - loss: 0.6925 - accuracy: 0.7090
# Epoch 21/25
# 98/98 [==============================] - 6s 61ms/step - loss: 0.6850 - accuracy: 0.7151
# Epoch 22/25
# 98/98 [==============================] - 5s 51ms/step - loss: 0.6763 - accuracy: 0.7209
# Epoch 23/25
# 98/98 [==============================] - 5s 53ms/step - loss: 0.6683 - accuracy: 0.7252
# Epoch 24/25
# 98/98 [==============================] - 5s 51ms/step - loss: 0.6630 - accuracy: 0.7285
# Epoch 25/25
# 98/98 [==============================] - 5s 48ms/step - loss: 0.6563 - accuracy: 0.7325
# 49/49 [==============================] - 2s 19ms/step - loss: 0.7637 - accuracy: 0.6775
# Model: "sequential_414"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_414 (Embedding)   (None, 79, 64)            320000
#
#  lstm_414 (LSTM)             (None, 64)                33024
#
#  dropout_414 (Dropout)       (None, 64)                0
#
#  dense_414 (Dense)           (None, 3)                 195
#
# =================================================================
# Total params: 353,219
# Trainable params: 353,219
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 98/98 [==============================] - 10s 72ms/step - loss: 0.8351 - accuracy: 0.6082
# Epoch 2/25
# 98/98 [==============================] - 8s 83ms/step - loss: 0.6550 - accuracy: 0.7269
# Epoch 3/25
# 98/98 [==============================] - 8s 80ms/step - loss: 0.5673 - accuracy: 0.7669
# Epoch 4/25
# 98/98 [==============================] - 7s 76ms/step - loss: 0.4915 - accuracy: 0.8015
# Epoch 5/25
# 98/98 [==============================] - 7s 74ms/step - loss: 0.4241 - accuracy: 0.8284
# Epoch 6/25
# 98/98 [==============================] - 7s 75ms/step - loss: 0.3673 - accuracy: 0.8532
# Epoch 7/25
# 98/98 [==============================] - 8s 77ms/step - loss: 0.3141 - accuracy: 0.8712
# Epoch 8/25
# 98/98 [==============================] - 8s 84ms/step - loss: 0.2693 - accuracy: 0.8889
# Epoch 9/25
# 98/98 [==============================] - 7s 76ms/step - loss: 0.2401 - accuracy: 0.9042
# Epoch 10/25
# 98/98 [==============================] - 7s 72ms/step - loss: 0.2139 - accuracy: 0.9150
# Epoch 11/25
# 98/98 [==============================] - 7s 70ms/step - loss: 0.1873 - accuracy: 0.9268
# Epoch 12/25
# 98/98 [==============================] - 7s 73ms/step - loss: 0.1607 - accuracy: 0.9361
# Epoch 13/25
# 98/98 [==============================] - 8s 83ms/step - loss: 0.1517 - accuracy: 0.9402
# Epoch 14/25
# 98/98 [==============================] - 10s 103ms/step - loss: 0.1450 - accuracy: 0.9436
# Epoch 15/25
# 98/98 [==============================] - 9s 88ms/step - loss: 0.1332 - accuracy: 0.9487
# Epoch 16/25
# 98/98 [==============================] - 12s 119ms/step - loss: 0.1191 - accuracy: 0.9540
# Epoch 17/25
# 98/98 [==============================] - 12s 126ms/step - loss: 0.1072 - accuracy: 0.9587
# Epoch 18/25
# 98/98 [==============================] - 14s 139ms/step - loss: 0.1112 - accuracy: 0.9589
# Epoch 19/25
# 98/98 [==============================] - 12s 122ms/step - loss: 0.1041 - accuracy: 0.9590
# Epoch 20/25
# 98/98 [==============================] - 12s 125ms/step - loss: 0.1047 - accuracy: 0.9603
# Epoch 21/25
# 98/98 [==============================] - 12s 127ms/step - loss: 0.1000 - accuracy: 0.9625
# Epoch 22/25
# 98/98 [==============================] - 12s 119ms/step - loss: 0.0976 - accuracy: 0.9627
# Epoch 23/25
# 98/98 [==============================] - 12s 126ms/step - loss: 0.0963 - accuracy: 0.9626
# Epoch 24/25
# 98/98 [==============================] - 12s 120ms/step - loss: 0.0856 - accuracy: 0.9682
# Epoch 25/25
# 98/98 [==============================] - 12s 119ms/step - loss: 0.0870 - accuracy: 0.9672
# 49/49 [==============================] - 4s 55ms/step - loss: 2.7679 - accuracy: 0.6204
# Model: "sequential_415"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_415 (Embedding)   (None, 79, 64)            320000
#
#  lstm_415 (LSTM)             (None, 64)                33024
#
#  dropout_415 (Dropout)       (None, 64)                0
#
#  dense_415 (Dense)           (None, 3)                 195
#
# =================================================================
# Total params: 353,219
# Trainable params: 353,219
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# 98/98 [==============================] - 18s 120ms/step - loss: 0.8189 - accuracy: 0.6213
# Epoch 2/25
# 98/98 [==============================] - 12s 122ms/step - loss: 0.6493 - accuracy: 0.7332
# Epoch 3/25
# 98/98 [==============================] - 13s 129ms/step - loss: 0.5610 - accuracy: 0.7737
# Epoch 4/25
# 98/98 [==============================] - 12s 118ms/step - loss: 0.4750 - accuracy: 0.8075
# Epoch 5/25
# 98/98 [==============================] - 12s 122ms/step - loss: 0.4021 - accuracy: 0.8349
# Epoch 6/25
# 98/98 [==============================] - 12s 125ms/step - loss: 0.3370 - accuracy: 0.8612
# Epoch 7/25
# 98/98 [==============================] - 12s 124ms/step - loss: 0.2915 - accuracy: 0.8819
# Epoch 8/25
# 98/98 [==============================] - 12s 123ms/step - loss: 0.2518 - accuracy: 0.8988
# Epoch 9/25
# 98/98 [==============================] - 12s 121ms/step - loss: 0.2245 - accuracy: 0.9088
# Epoch 10/25
# 98/98 [==============================] - 12s 121ms/step - loss: 0.1968 - accuracy: 0.9221
# Epoch 11/25
# 98/98 [==============================] - 13s 128ms/step - loss: 0.1763 - accuracy: 0.9314
# Epoch 12/25
# 98/98 [==============================] - 12s 122ms/step - loss: 0.1576 - accuracy: 0.9375
# Epoch 13/25
# 98/98 [==============================] - 12s 125ms/step - loss: 0.1435 - accuracy: 0.9446
# Epoch 14/25
# 98/98 [==============================] - 13s 130ms/step - loss: 0.1411 - accuracy: 0.9459
# Epoch 15/25
# 98/98 [==============================] - 12s 122ms/step - loss: 0.1263 - accuracy: 0.9517
# Epoch 16/25
# 64/98 [==================>...........] - ETA: 4s - loss: 0.1111 - accuracy: 0.9580

# %%
model = KerasClassifier(build_fn = create_model,
                        # Model Parameters
                        dropout_rate = 0.2,
                        embed_dim = 32,
                        hidden_unit = 64,
                        optimizers = RMSprop,
                        learning_rate = 0.001,
                   
                        # Fit Parameters
                        epochs=10, 
                        batch_size=256,
                        # Initiate validation data, which is 10% data from data train. It's used for evaluation model
                        validation_split = 0.1)
                         

model_prediction = model.fit(X_train, y_train)

# %%
# Visualization model accuracy (train and val accuracy)

fig, ax = plt.subplots(figsize = (10, 4))
ax.plot(model_prediction.history['accuracy'], label = 'train accuracy')
ax.plot(model_prediction.history['val_accuracy'], label = 'val accuracy')
ax.set_title('Model Accuracy')
ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.legend(loc = 'upper left')
plt.show()

# %%
# Predict sentiment on data test by using model has been created, and then visualize a confusion matrix


y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('Model Accuracy on Test Data:', accuracy)
confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize = (8,6))
sns.heatmap(confusion_matrix(y_true = y_test, y_pred = y_pred), fmt = 'g', annot = True)
ax.xaxis.set_label_position('top')
ax.xaxis.set_ticks_position('top')
ax.set_xlabel('Prediction', fontsize = 14)
ax.set_xticklabels(['negative (0)', 'neutral (1)', 'positive (2)'])
ax.set_ylabel('Actual', fontsize = 14)
ax.set_yticklabels(['negative (0)', 'neutral (1)', 'positive (2)'])
plt.show()

# %%
# Results from prediction sentiment on data test
text_clean = tweets['Clean_Text']
text_train, text_test = train_test_split(text_clean, test_size = 0.2, random_state = 0)
result_test = pd.DataFrame(data = zip(text_test, y_pred), columns = ['text', 'polarity'])
polarity_decode = {0 : 'Negative', 1 : 'Neutral', 2 : 'Positive'}
result_test['polarity'] = result_test['polarity'].map(polarity_decode)
pd.set_option('max_colwidth', 300)
result_test

# %%
# Initializing and preprocessing new text data
otherData = pd.DataFrame()
otherData['text'] = ['metaverse teknologi yang sangat menjanjikan',
                     'Tapi serius deh semakin kesini ngerasa kuliah online makin ga efektif, ga paham materi blasss, kopong, berasa yauda kek ga kuliah' 
                    ]

otherData['text_clean'] = otherData['text'].apply(cleaningText)
otherData['text_clean'] = otherData['text_clean'].apply(casefoldingText)
otherData.drop(['text'], axis = 1, inplace = True)

otherData['text_preprocessed'] = otherData['text_clean'].apply(tokenizingText)
otherData['text_preprocessed'] = otherData['text_preprocessed'].apply(filteringText)
otherData['text_preprocessed'] = otherData['text_preprocessed'].apply(stemmingText)
otherData

# %%
# Preprocessing text data

# Make text preprocessed (tokenized) to untokenized with toSentence Function
X_otherData = otherData['text_preprocessed'].apply(toSentence)
X_otherData = tokenizer.texts_to_sequences(X_otherData.values)
X_otherData = pad_sequences(X_otherData, maxlen = X.shape[1])
X_otherData

# %%
# Results from prediction sentiment on text data

y_pred_otherData = model.predict(X_otherData)
otherData['Result Prediction'] = y_pred_otherData

polarity_decode = {0 : 'Negative', 1 : 'Neutral', 2 : 'Positive'}
otherData['Result Prediction'] = otherData['Result Prediction'].map(polarity_decode)
otherData
