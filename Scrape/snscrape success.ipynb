# %%
# !pip install --upgrade snscrape

# %%
# !snscrape --version
# Out:
# snscrape 0.7.0.20230622

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
query = 'id'
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(
    'metaverse since:2023-01-01 until:2023-01-31 lang:id -filter:retweets ').get_items()):
    if i>20000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.user.location])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Text',])
tweets_df2.to_csv("C:/Users/Juniarta/Krispi/Dataset/twitter_2023_01.csv")
# Out:
# Error retrieving https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22metaverse%20since%3A2023-01-01%20until%3A2023-01-31%20lang%3Aid%20-filter%3Aretweets%20%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_r
# ...

# %%
print(len(tweets_list2))

# %%
for tweet in tweets_list2:
    print(tweet)
# Out:
# [datetime.datetime(2022, 12, 30, 23, 32, 3, tzinfo=datetime.timezone.utc), 1608969192648343552, '@ikidyah Pacaran metaverse 😎', 'Tuheq']
# [datetime.datetime(2022, 12, 30, 22, 46, 11, tzinfo=datetime.timezone.utc), 1608957650791968768, 'Bdw, i really love this game. Ini tuh sosmed yang dibungkus dalam game. Metaverse sih emang. Pokoknya mutual gue harus liat dan buru joinnnn https://t.co/bZ01z4Z8vf', 'mooncalfdung']
# [datetime.datetime(2022, 12, 30, 21, 22, 19, tzinfo=datetime.timezone.utc), 1608936543229734912, 'Kepada Bapak Presiden Jokowi @jokowi \nStelah CRYPTO sedikit mulai diterima bukan sebatas ASET KOMODITAS\n\nSpertinya juga penting menyiapkan diri dlm konteks METAVERSE\n\nSeperti salah satu artikel dibawah ini\n👇👇👇\nhttps://t.co/f7QS1c4wTa\nIndonesia memiliki POTENSI utk dikembangkan https://t.co/xW3VXbTbol', 'Rega20211']
# [datetime.datetime(2022, 12, 30, 20, 1, 53, tzinfo=datetime.timezone.utc), 1608916301099208704, 'anying lanjut bahas metaverse', 'etzqtn']
# ...

# %%
tweets_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4557 entries, 0 to 4556
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Datetime  4557 non-null   datetime64[ns, UTC]
#  1   Tweet Id  4557 non-null   int64
#  2   Text      4557 non-null   object
#  3   Username  4557 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(1), object(2)
# memory usage: 142.5+ KB
